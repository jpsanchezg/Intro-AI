# %% [markdown]
# # Mi primer notebook para python
# ## Probando librerias

# %% [markdown]
# Este es un notebook orientado a las primeras aproximaciones de jupyter lab con kernel python

# %% [markdown]
# ### importacion del librerias

# %%
import pandas as pd
import numpy as nm
from pandas_profiling import ProfileReport

# %% [markdown]
# # carga de datos empleando pandas

# %%
datos_iris = pd.read_csv("iris.csv", names=["sepal length","sepal width","petal length","petal width","class"],sep=",")

# %% [markdown]
# Muestra de datos

# %%
datos_iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Agrupando  los datos por clase

# %%
grouped_data = datos_iris.groupby('class')

# %% [markdown]
# ## Sacando las estadísticas para todas las columnas numéricas por clase

# %%
grouped_data.describe()
# Out:
#                 sepal length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal width         ... petal length      petal width         \
#                       count   mean  ...          75%  max       count   mean
# class                               ...
# Iris-setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# Iris-versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Iris-virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# class
# Iris-setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# ...

# %% [markdown]
# ## la media de cada columna numérica por clase de flor

# %%
grouped_data.mean()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# ## Escribiendo el csv con las estadisticas de las flores

# %%
nuevodatos = grouped_data.describe()

# %%
nuevodatos
# Out:
#                 sepal length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal width         ... petal length      petal width         \
#                       count   mean  ...          75%  max       count   mean
# class                               ...
# Iris-setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# Iris-versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Iris-virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# class
# Iris-setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# ...

# %% [markdown]
# ### Escribiendo en un nuevo archivo csv con las nuevas columnas que se añadieron

# %%
nuevodatos.to_csv('estadisticasDeIris.csv', index=False, sep=',')

# %% [markdown]
# ## Lectora de datos de un excel
# Se hace lectura de un archivo csv primero para luego ser transformaco a tipo excel

# %%
adultodf = pd.read_csv("adult.csv",index_col=False,names=["Age","Workclass","Fnlwgt","Education","education-num","Marital-status","Occupation","Relationship","Race","Sex","Capital-gain","Capital-loss","Hours-per-week","Native-country","Population"],sep=",")
adultodf
# Out:
#        Age          Workclass  Fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ## Creando el archivo excel convirtiendo el data frame de adultodf a un archivo excel

# %%
adultodf.to_excel("adultoexcel.xlsx",sheet_name='Sheet_name_1',index=False)

# %% [markdown]
# ### Lectura del archivo excel para ser usado como data frame

# %%
adultodfex = pd.read_excel("adultoexcel.xlsx")
adultodfex
# Out:
#        Age          Workclass  Fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# Contando por edad la educacion que tienen en total

# %%
group_educationxAge = adultodfex.groupby(['Age', 'Education']).size()
dfeducationxAge = group_educationxAge.to_frame(name = 'Total').reset_index()
dfeducationxAge
# Out:
#      Age      Education  Total
# 0     17           10th    138
# 1     17           11th    180
# 2     17           12th     37
# 3     17        5th-6th      1
# 4     17        7th-8th      3
# ..   ...            ...    ...
# 960   90      Bachelors      9
# 961   90        HS-grad     14
# 962   90        Masters      4
# 963   90    Prof-school      1
# 964   90   Some-college      6
#
# [965 rows x 3 columns]

# %% [markdown]
# ## Creando el archivo excel con el dataframe de educationxAge

# %%
dfeducationxAge.to_excel("totalxedadyedudacion.xlsx",sheet_name='Sheet_name_1',index=False)

# %% [markdown]
# # Lectura de un archivo JSON
# Se va a hacer una lectura y escritura de un archivo JSON

# %%
dfJson = pd.read_json("unece.json")
dfJson
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %% [markdown]
# ## Agrupando por pais y por poblacion

# %%
groupbyyearndcountry = dfJson.groupby(['Country', 'Total population'])
newdfjson = groupbyyearndcountry.describe()
newdfjson
# Out:
#                              Year                                              \
#                             count    mean std     min     25%     50%     75%
# Country    Total population
# Albania    2801681.0          1.0  2012.0 NaN  2012.0  2012.0  2012.0  2012.0
#            2829337.0          1.0  2011.0 NaN  2011.0  2011.0  2011.0  2011.0
#            2856673.0          1.0  2010.0 NaN  2010.0  2010.0  2010.0  2010.0
#            2889167.0          1.0  2015.0 NaN  2015.0  2015.0  2015.0  2015.0
#            2893654.0          1.0  2014.0 NaN  2014.0  2014.0  2014.0  2014.0
# ...                           ...     ...  ..     ...     ...     ...     ...
# Uzbekistan 29339368.0         1.0  2011.0 NaN  2011.0  2011.0  2011.0  2011.0
#            29774448.0         1.0  2012.0 NaN  2012.0  2012.0  2012.0  2012.0
#            30243172.0         1.0  2013.0 NaN  2013.0  2013.0  2013.0  2013.0
#            30757669.0         1.0  2014.0 NaN  2014.0  2014.0  2014.0  2014.0
# ...

# %%
newdfjson.to_json("countrysXpopulation.json")

# %%
lecturaC = pd.read_json("countrysXpopulation.json")
lecturaC
# Out:
#                             ('Year', 'count')  ('Year', 'mean')  \
# ('Albania', 2801681.0)                      1              2012
# ('Albania', 2829337.0)                      1              2011
# ('Albania', 2856673.0)                      1              2010
# ('Albania', 2889167.0)                      1              2015
# ('Albania', 2893654.0)                      1              2014
# ...                                       ...               ...
# ('Uzbekistan', 29339368.0)                  1              2011
# ('Uzbekistan', 29774448.0)                  1              2012
# ('Uzbekistan', 30243172.0)                  1              2013
# ('Uzbekistan', 30757669.0)                  1              2014
# ('Uzbekistan', 31298929.0)                  1              2015
#
#                             ('Year', 'std')  ('Year', 'min')  ('Year', '25%')  \
# ('Albania', 2801681.0)                  NaN             2012             2012
# ...
